MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from xgboost import XGBRegressor

import pickle

df = pd.read_csv("demand_forecasting.csv")

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='object')

# %%
features = [
    "Price",
    "Discount",
    "Inventory Level",
    "Promotion",
    "Competitor Pricing",
    "Category"
]

features
# Out:
# ['Price',
#  'Discount',
#  'Inventory Level',
#  'Promotion',
#  'Competitor Pricing',
#  'Category']

# %%
target = "Demand"

# %%
X=df[features].copy()

# %%
X
# Out:
#         Price  Discount  Inventory Level  Promotion  Competitor Pricing  \
# 0       72.72         5              195          0               85.73
# 1       80.16        15              117          1               92.02
# 2       62.94        10              247          1               60.08
# 3       87.63        10              139          0               85.19
# 4       54.41         0              152          0               51.63
# ...       ...       ...              ...        ...                 ...
# 75995   29.80         5              233          0               32.23
# 75996   42.92         5              137          0               40.73
# 75997   17.81        10              197          0               19.41
# 75998  151.72         0              125          0              143.71
# 75999   25.78        10              126          0               29.32
#
#           Category
# 0      Electronics
# 1         Clothing
# 2         Clothing
# 3      Electronics
# 4        Groceries
# ...            ...
# 75995         Toys
# 75996         Toys
# 75997     Clothing
# 75998    Furniture
# 75999         Toys
#
# [76000 rows x 6 columns]

# %%
Y=df[target].copy()

# %%
Y
# Out:
# 0        115
# 1        229
# 2        157
# 3         52
# 4         59
#         ...
# 75995     64
# 75996    137
# 75997     68
# 75998     84
# 75999     73
# Name: Demand, Length: 76000, dtype: int64

# %%
label_encoders = {}

categorical_cols = X.select_dtypes(include="object").columns

categorical_cols
# Out:
# Index(['Category'], dtype='object')

# %%
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le

label_encoders
# Out:
# {'Category': LabelEncoder()}

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
xgb = XGBRegressor(objective="reg:squarederror", n_jobs=-1)

# %%
param_dict = {
    "n_estimators": [200, 300, 500],
    "max_depth": [3, 4, 6, 8],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.7, 0.8, 1.0],
    "min_child_weight": [1, 3, 5]
}

# %%
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dict,
    n_iter=25,
    scoring="neg_mean_absolute_error",
    cv=3,
    verbose=1,
    n_jobs=-1
)

random_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=True,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints...
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=-1,
#                                           num_parallel_tree=None, ...),
#                    n_iter=25, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 4, 6, 8],
#                                         'min_child_weight': [1, 3, 5],
#                                         'n_estimators': [200, 300, 500],
#                                         'subsample': [0.7, 0.8, 1.0]},
#                    scoring='neg_mean_absolute_error', verbose=1)

# %%
random_search.best_params_
# Out:
# {'subsample': 0.8,
#  'n_estimators': 300,
#  'min_child_weight': 1,
#  'max_depth': 8,
#  'learning_rate': 0.05,
#  'colsample_bytree': 1.0}

# %%
best_model = random_search.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error(Y_test, y_pred)
rmse
# Out:
# 35.21380615234375

# %%
best_model.feature_importances_
# Out:
# array([0.07372442, 0.02210239, 0.02461504, 0.5994395 , 0.02740037,
#        0.25271827], dtype=float32)

# %%
feature_importance = pd.Series(
    best_model.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

feature_importance
# Out:
# Promotion             0.599440
# Category              0.252718
# Price                 0.073724
# Competitor Pricing    0.027400
# Inventory Level       0.024615
# Discount              0.022102
# dtype: float32

# %%
feature_importance.plot(kind="bar")
# Out:
# <Axes: >

# %%
with open("label_encoders.pkl", "wb") as f:
    pickle.dump(label_encoders, f)

# %%
with open("xgboost_demand_model.pkl", "wb") as f:
    pickle.dump(best_model, f)
